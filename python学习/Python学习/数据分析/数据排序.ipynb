# %%
# 在进行数据排序时，分别是:升序和降序。而基于Pandas进行数据排序时，是可以按照多个列进行排序的。
import pandas as pd

# 读取数据 read_csv
df = pd.read_csv("G:\Python程序设计\网络机器人\csv_data\movie_list.csv")
# 排序m
# df.sort_values('电影年份',ascending=False) #降序False 升序 True
# 多列排序：进行多个列排序时，会先按照第一列进行排序，第一列的值相同时，才会按照第二列进行排序。
df.sort_values(['电影年份','电影时长'],ascending=[False,True]) #降序False 升序 True
# Out:
# <>:5: SyntaxWarning: invalid escape sequence '\P'
# <>:5: SyntaxWarning: invalid escape sequence '\P'
# C:\Users\32651\AppData\Local\Temp\ipykernel_21204\3449745007.py:5: SyntaxWarning: invalid escape sequence '\P'
#   df = pd.read_csv("G:\Python程序设计\网络机器人\csv_data\movie_list.csv")
#             电影名字  电影年份        上映时间         电影类型  电影时长  电影评分         电影导演  \
# 52      惩罚者：最后一击  2026  2026-05-12     动作,剧情,犯罪     0    84  雷纳尔多·马库斯·格林
# 0        奇幻变身大冒险  2026  2026-05-01  冒险,动画,家庭,奇幻   102    90       内森·格雷诺
# 6        幸运有八只触手  2026  2026-05-08        剧情,悬疑   114    86      奥利维亚·纽曼
# 53  迈克尔·杰克逊：巨星之路  2026  2026-04-24        音乐,剧情   136    84      安东尼·福奎阿
# 3           挽救计划  2026  2026-03-20        科幻,冒险   157    87        菲尔·洛德
# ..           ...   ...         ...          ...   ...   ...          ...
# 81          日落大道  1950  2026-04-16           剧情   110    83       比利·怀尔德
# 76         生活多美好  1946  1946-12-20     剧情,家庭,奇幻   131    83      弗兰克·卡普拉
# ...
