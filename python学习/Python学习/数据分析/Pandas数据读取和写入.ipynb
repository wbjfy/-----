# %%
# 基于Pandas中提供的API，可以很方便的各类数据文件(csv、Excel、数据库、网络数据等)的读取和写入
import pandas as pd

# 读取数据 read_csv
df = pd.read_csv("G:\Python程序设计\网络机器人\csv_data\movie_list.csv",usecols=['电影名字','电影年份','电影时长'])

# 数据处理
df['数据和'] = df['电影年份'] + df['电影时长']

# 写入数据  to_csv
df.to_csv('G:\Python程序设计\网络机器人\csv_data\movie_list_01.csv',index=False)
# Out:
# <>:5: SyntaxWarning: invalid escape sequence '\P'
# <>:11: SyntaxWarning: invalid escape sequence '\P'
# <>:5: SyntaxWarning: invalid escape sequence '\P'
# <>:11: SyntaxWarning: invalid escape sequence '\P'
# C:\Users\32651\AppData\Local\Temp\ipykernel_24520\3472659173.py:5: SyntaxWarning: invalid escape sequence '\P'
#   df = pd.read_csv("G:\Python程序设计\网络机器人\csv_data\movie_list.csv",usecols=['电影名字','电影年份','电影时长'])
# C:\Users\32651\AppData\Local\Temp\ipykernel_24520\3472659173.py:11: SyntaxWarning: invalid escape sequence '\P'
#   df.to_csv('G:\Python程序设计\网络机器人\csv_data\movie_list_01.csv',index=False)
