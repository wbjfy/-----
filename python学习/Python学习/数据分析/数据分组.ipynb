# %%
import pandas as pd

# 读取数据 read_csv
df = pd.read_csv("G:\Python程序设计\网络机器人\csv_data\movie_list.csv")
# 分组操作就是吧数据按照某个特征分成不同的组，然后对每个组分别进行统计计算
# Out:
# <>:4: SyntaxWarning: invalid escape sequence '\P'
# <>:4: SyntaxWarning: invalid escape sequence '\P'
# C:\Users\32651\AppData\Local\Temp\ipykernel_34264\2280879169.py:4: SyntaxWarning: invalid escape sequence '\P'
#   df = pd.read_csv("G:\Python程序设计\网络机器人\csv_data\movie_list.csv")
