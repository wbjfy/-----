# %%
import pandas as pd

# 构造DataFrame -- 船舰数据集(学员成绩信息)
df = pd.DataFrame([
    {"姓名":"小王","语文":90,"数学":80,"英语":94},
    {"姓名":"小李","语文":92,"数学":88,"英语":83},
    {"姓名":"小张","语文":86,"数学":91,"英语":86},
    {"姓名":"小赵","语文":78,"数学":87,"英语":75},

])

# 统计计算
print(f"{df['语文'].max()},{df['语文'].min()},{df['语文'].mean()}")
print(f"{df['数学'].max()},{df['数学'].min()},{df['数学'].mean()}")
print(f"{df['英语'].max()},{df['英语'].min()},{df['英语'].mean()}")

# df.index.tolist() # 索引
# df.columns.tolist() # 列名
# df.values.tolist() # 值
# df.size # 元素个数
# df.dtypes # 数据类型
# df.shape # 维度
# Out:
# 92,78,86.5
# 91,80,86.5
# 94,75,84.5
# (4, 4)

# %%
# Series 创建
s1 = pd.Series([1,2,3,4,5,6])
s2 = pd.Series((1,2,3,4,5,6),index = ['a','b','c','d','e','f'])
s3 = pd.Series({'a':1,'b':2,'c':3,'d':4,'e':5,'f':6})
s4 = df['语文']
s4
# Out:
# 0    90
# 1    92
# 2    86
# 3    78
# Name: 语文, dtype: int64
